# %%
import pandas as pd
import pickle
import requests
import json

# %%
df = pd.read_csv('data/cleaned_data.csv')
df_json = df.to_json(orient='records')
r = requests.post('http://127.0.0.1:8000/prediction/', data=df_json).json()
r
# Out:
# [2,
#  2,
#  0,
#  2,
#  1,
#  3,
#  3,
#  0,
#  3,
#  3,
#  2,
#  2,
#  3,
#  1,
#  1,
#  0,
#  1,
#  3,
#  1,
#  0,
#  4,
#  1,
#  2,
#  3,
#  0,
#  4,
#  3,
#  4,
#  0,
#  3,
#  2,
#  2,
#  3,
#  3,
#  4,
#  2,
#  4,
#  0,
#  1,
#  2,
#  3,
#  0,
#  2,
#  0,
#  0,
#  2,
#  0,
#  3,
#  3,
#  3,
#  0,
#  0,
#  0,
#  4,
#  0,
#  5,
#  2,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  3,
#  0,
#  0,
#  0,
#  3,
#  2,
#  0,
#  3,
#  4,
#  2,
#  0,
#  3,
#  0,
#  2,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  0,
#  3,
#  0,
#  2,
#  2,
#  0,
#  3,
#  0,
#  1,
#  0,
#  1,
#  0,
#  3,
#  3,
#  1,
#  0,
#  0,
#  1,
#  0,
#  0,
#  4,
#  0,
#  3,
#  2,
#  2,
#  4,
#  3,
#  3,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  5,
#  0,
#  2,
#  2,
#  0,
#  1,
#  5,
#  1,
#  5,
#  3,
#  1,
#  0,
#  0,
#  2,
#  2,
#  0,
#  2,
#  0,
#  4,
#  3,
#  4,
#  2,
#  1,
#  2,
#  1,
#  1,
#  0,
#  2,
#  3,
#  3,
#  0,
#  2,
#  0,
#  5,
#  3,
#  3,
#  1,
#  5,
#  3,
#  2,
#  2,
#  3,
#  1,
#  2,
#  3,
#  2,
#  3,
# ...
